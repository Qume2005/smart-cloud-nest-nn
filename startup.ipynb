# %%
import torch
from torch import nn
from torch.utils.data import DataLoader

from nn_train import *
from main_nn_module import *
from torch_dataset import *
from utils.split import *

# %%
device = "mps"

# %%
def calculate_model_size():
    # 创建模型实例
    nn_model = MainNnModule()

    # 计算总参数量
    total_params = sum(p.numel() for p in nn_model.parameters() if p.requires_grad)

    # 转换为千参数单位
    params_in_k = total_params / 1000

    # 创建模拟输入（单通道，10x16输入）
    dummy_input = torch.randn(1, 1, 10, 16)

    # 测试前向传播
    output = nn_model(dummy_input)

    return total_params, params_in_k, output.shape

# %%
model = MainNnModule().to(device)
optimizer = optim.AdamW(model.parameters())
loss_fn = nn.CrossEntropyLoss()

dataset = JQDataset("./datas/dataset.csv")
train_set, test_set = stratified_split(dataset, test_size=0.2)

train_dataloader = DataLoader(train_set, batch_size=8, shuffle=True)
test_dataloader = DataLoader(test_set, batch_size=8, shuffle=True)

# %%
epochs = 64
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer, device)
    test(test_dataloader, model, loss_fn, device)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.208029  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.110210
#
# Epoch 2
# -------------------------------
# loss: 1.122810  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.113658
#
# Epoch 3
# -------------------------------
# loss: 1.119207  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.134094
#
# Epoch 4
# -------------------------------
# loss: 1.106864  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.096844
#
# Epoch 5
# -------------------------------
# loss: 1.064164  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.113546
#
# Epoch 6
# -------------------------------
# loss: 1.171954  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.106164
#
# Epoch 7
# -------------------------------
# loss: 1.041249  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.108452
#
# Epoch 8
# -------------------------------
# loss: 1.088234  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.105810
#
# Epoch 9
# -------------------------------
# loss: 1.050624  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.094808
#
# Epoch 10
# -------------------------------
# loss: 1.115954  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.104288
#
# Epoch 11
# -------------------------------
# loss: 1.110117  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.088773
#
# Epoch 12
# -------------------------------
# loss: 1.104587  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.108461
#
# Epoch 13
# -------------------------------
# loss: 1.081410  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.099618
#
# Epoch 14
# -------------------------------
# loss: 1.137965  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.105891
#
# Epoch 15
# -------------------------------
# loss: 1.114192  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.098475
#
# Epoch 16
# -------------------------------
# loss: 1.096351  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.100127
#
# Epoch 17
# -------------------------------
# loss: 1.099336  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.102645
#
# Epoch 18
# -------------------------------
# loss: 1.089687  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.097550
#
# Epoch 19
# -------------------------------
# loss: 1.091781  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.096945
#
# Epoch 20
# -------------------------------
# loss: 1.090851  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.098338
#
# Epoch 21
# -------------------------------
# loss: 1.077694  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.092014
#
# Epoch 22
# -------------------------------
# loss: 1.088381  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.096534
#
# Epoch 23
# -------------------------------
# loss: 1.088166  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.091740
#
# Epoch 24
# -------------------------------
# loss: 1.093893  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.095373
#
# Epoch 25
# -------------------------------
# loss: 1.089151  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.098889
#
# Epoch 26
# -------------------------------
# loss: 1.099512  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.093936
#
# Epoch 27
# -------------------------------
# loss: 1.100800  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.094771
#
# Epoch 28
# -------------------------------
# loss: 1.088924  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.090847
#
# Epoch 29
# -------------------------------
# loss: 1.091588  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.088373
#
# Epoch 30
# -------------------------------
# loss: 1.093454  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.088605
#
# Epoch 31
# -------------------------------
# loss: 1.072802  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.087945
#
# Epoch 32
# -------------------------------
# loss: 1.112401  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.082708
#
# Epoch 33
# -------------------------------
# loss: 1.074801  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.072857
#
# Epoch 34
# -------------------------------
# loss: 1.087982  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.072488
#
# Epoch 35
# -------------------------------
# loss: 1.047108  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 1.055951
#
# Epoch 36
# -------------------------------
# loss: 1.078276  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 1.047229
#
# Epoch 37
# -------------------------------
# loss: 1.064389  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 1.016041
#
# Epoch 38
# -------------------------------
# loss: 0.998764  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.987179
#
# Epoch 39
# -------------------------------
# loss: 1.047840  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.948329
#
# Epoch 40
# -------------------------------
# loss: 0.998885  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.920985
#
# Epoch 41
# -------------------------------
# loss: 0.886539  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.882615
#
# Epoch 42
# -------------------------------
# loss: 0.940427  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.853432
#
# Epoch 43
# -------------------------------
# loss: 0.941360  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.815432
#
# Epoch 44
# -------------------------------
# loss: 0.798249  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.797056
#
# Epoch 45
# -------------------------------
# loss: 0.918586  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.774245
#
# Epoch 46
# -------------------------------
# loss: 0.960548  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.754581
#
# Epoch 47
# -------------------------------
# loss: 0.967413  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.786114
#
# Epoch 48
# -------------------------------
# loss: 0.835683  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.743168
#
# Epoch 49
# -------------------------------
# loss: 0.662771  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.707270
#
# Epoch 50
# -------------------------------
# loss: 0.858252  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.691298
#
# Epoch 51
# -------------------------------
# loss: 0.997218  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.706003
#
# Epoch 52
# -------------------------------
# loss: 0.951599  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.731534
#
# Epoch 53
# -------------------------------
# loss: 0.629849  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.705219
#
# Epoch 54
# -------------------------------
# loss: 0.606026  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.745033
#
# Epoch 55
# -------------------------------
# loss: 0.625620  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.713714
#
# Epoch 56
# -------------------------------
# loss: 0.839836  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.724827
#
# Epoch 57
# -------------------------------
# loss: 0.776107  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.688385
#
# Epoch 58
# -------------------------------
# loss: 0.657861  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.691597
#
# Epoch 59
# -------------------------------
# loss: 0.789112  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.666180
#
# Epoch 60
# -------------------------------
# loss: 0.582069  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.714585
#
# Epoch 61
# -------------------------------
# loss: 0.691807  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.739570
#
# Epoch 62
# -------------------------------
# loss: 0.558213  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.622083
#
# Epoch 63
# -------------------------------
# loss: 0.791180  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.626238
#
# Epoch 64
# -------------------------------
# loss: 0.628917  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.602843
#
# Done!

# %%
total_params, params_in_k, output_shape = calculate_model_size()

print(f"模型总参数量: {total_params}")
print(f"以k为单位的参数量: {params_in_k:.2f}k")
print(f"输出形状: {output_shape}")
# Out:
# 模型总参数量: 1031
# 以k为单位的参数量: 1.03k
# 输出形状: torch.Size([1, 3])

# %%
torch.save(model,'./model.pt')
