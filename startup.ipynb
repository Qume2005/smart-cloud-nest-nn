# %%
import torch
from torch import nn
from torch.utils.data import DataLoader

from nn_train import *
from main_nn_module import *
from torch_dataset import *
from utils.split import *

# %%
device = "mps"

# %%
def calculate_model_size():
    # 创建模型实例
    nn_model = MainNnModule()

    # 计算总参数量
    total_params = sum(p.numel() for p in nn_model.parameters() if p.requires_grad)

    # 转换为千参数单位
    params_in_k = total_params / 1000

    # 创建模拟输入（单通道，10x16输入）
    dummy_input = torch.randn(1, 1, 10, 16)

    # 测试前向传播
    output = nn_model(dummy_input)

    return total_params, params_in_k, output.shape

# %%
model = MainNnModule().to(device)
optimizer = optim.AdamW(model.parameters())
loss_fn = nn.CrossEntropyLoss()

dataset = JQDataset("./datas/dataset.csv")
train_set, test_set = stratified_split(dataset, test_size=0.2)

train_dataloader = DataLoader(train_set, batch_size=8, shuffle=True)
test_dataloader = DataLoader(test_set, batch_size=8, shuffle=True)

# %%
epochs = 64
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer, device)
    test(test_dataloader, model, loss_fn, device)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.213304  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.179027
#
# Epoch 2
# -------------------------------
# loss: 1.101894  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.109717
#
# Epoch 3
# -------------------------------
# loss: 1.047592  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.143495
#
# Epoch 4
# -------------------------------
# loss: 1.097599  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.175939
#
# Epoch 5
# -------------------------------
# loss: 1.162389  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.111245
#
# Epoch 6
# -------------------------------
# loss: 1.162198  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.120372
#
# Epoch 7
# -------------------------------
# loss: 1.126074  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.093924
#
# Epoch 8
# -------------------------------
# loss: 1.109545  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.096557
#
# Epoch 9
# -------------------------------
# loss: 1.094730  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.095697
#
# Epoch 10
# -------------------------------
# loss: 1.094161  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.098963
#
# Epoch 11
# -------------------------------
# loss: 1.103220  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.100029
#
# Epoch 12
# -------------------------------
# loss: 1.108825  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.093860
#
# Epoch 13
# -------------------------------
# loss: 1.090073  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.089724
#
# Epoch 14
# -------------------------------
# loss: 1.092009  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.093751
#
# Epoch 15
# -------------------------------
# loss: 1.089849  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.096316
#
# Epoch 16
# -------------------------------
# loss: 1.074655  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.090886
#
# Epoch 17
# -------------------------------
# loss: 1.083370  [    8/   47]
# Test Error:
#  Accuracy: 33.3%, Avg loss: 1.092716
#
# Epoch 18
# -------------------------------
# loss: 1.100860  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.089134
#
# Epoch 19
# -------------------------------
# loss: 1.084885  [    8/   47]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 1.090181
#
# Epoch 20
# -------------------------------
# loss: 1.085794  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 1.084939
#
# Epoch 21
# -------------------------------
# loss: 1.096443  [    8/   47]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 1.085273
#
# Epoch 22
# -------------------------------
# loss: 1.079689  [    8/   47]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 1.082691
#
# Epoch 23
# -------------------------------
# loss: 1.079413  [    8/   47]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 1.083976
#
# Epoch 24
# -------------------------------
# loss: 1.068133  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.085293
#
# Epoch 25
# -------------------------------
# loss: 1.009812  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 1.067620
#
# Epoch 26
# -------------------------------
# loss: 1.068286  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.063109
#
# Epoch 27
# -------------------------------
# loss: 1.047698  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.052600
#
# Epoch 28
# -------------------------------
# loss: 1.016549  [    8/   47]
# Test Error:
#  Accuracy: 41.7%, Avg loss: 1.022796
#
# Epoch 29
# -------------------------------
# loss: 1.027180  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 0.996804
#
# Epoch 30
# -------------------------------
# loss: 1.106969  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 0.993914
#
# Epoch 31
# -------------------------------
# loss: 1.026317  [    8/   47]
# Test Error:
#  Accuracy: 50.0%, Avg loss: 0.952883
#
# Epoch 32
# -------------------------------
# loss: 0.897150  [    8/   47]
# Test Error:
#  Accuracy: 58.3%, Avg loss: 0.909363
#
# Epoch 33
# -------------------------------
# loss: 0.950763  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.865318
#
# Epoch 34
# -------------------------------
# loss: 0.959940  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.781290
#
# Epoch 35
# -------------------------------
# loss: 0.896351  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.791613
#
# Epoch 36
# -------------------------------
# loss: 0.904383  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.748645
#
# Epoch 37
# -------------------------------
# loss: 0.875193  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.830758
#
# Epoch 38
# -------------------------------
# loss: 0.705036  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.804714
#
# Epoch 39
# -------------------------------
# loss: 0.732160  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.771854
#
# Epoch 40
# -------------------------------
# loss: 0.813017  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.698972
#
# Epoch 41
# -------------------------------
# loss: 0.720445  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.729265
#
# Epoch 42
# -------------------------------
# loss: 0.872075  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.734448
#
# Epoch 43
# -------------------------------
# loss: 0.791873  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.696306
#
# Epoch 44
# -------------------------------
# loss: 0.852341  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.735620
#
# Epoch 45
# -------------------------------
# loss: 0.733741  [    8/   47]
# Test Error:
#  Accuracy: 66.7%, Avg loss: 0.712231
#
# Epoch 46
# -------------------------------
# loss: 0.774261  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.709804
#
# Epoch 47
# -------------------------------
# loss: 0.655338  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.697952
#
# Epoch 48
# -------------------------------
# loss: 0.554906  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.731472
#
# Epoch 49
# -------------------------------
# loss: 0.873236  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.674882
#
# Epoch 50
# -------------------------------
# loss: 0.611239  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.677187
#
# Epoch 51
# -------------------------------
# loss: 0.823376  [    8/   47]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.689888
#
# Epoch 52
# -------------------------------
# loss: 0.565888  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.620349
#
# Epoch 53
# -------------------------------
# loss: 0.698987  [    8/   47]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.657340
#
# Epoch 54
# -------------------------------
# loss: 0.823365  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.631186
#
# Epoch 55
# -------------------------------
# loss: 0.690636  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.675424
#
# Epoch 56
# -------------------------------
# loss: 0.683995  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.648318
#
# Epoch 57
# -------------------------------
# loss: 1.018531  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.644044
#
# Epoch 58
# -------------------------------
# loss: 0.540967  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.605508
#
# Epoch 59
# -------------------------------
# loss: 0.720770  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.652180
#
# Epoch 60
# -------------------------------
# loss: 0.631983  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.640874
#
# Epoch 61
# -------------------------------
# loss: 0.628497  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.621964
#
# Epoch 62
# -------------------------------
# loss: 0.662084  [    8/   47]
# Test Error:
#  Accuracy: 91.7%, Avg loss: 0.613358
#
# Epoch 63
# -------------------------------
# loss: 0.621426  [    8/   47]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.592083
#
# Epoch 64
# -------------------------------
# loss: 0.510011  [    8/   47]
# Test Error:
#  Accuracy: 100.0%, Avg loss: 0.622345
#
# Done!

# %%
total_params, params_in_k, output_shape = calculate_model_size()

print(f"模型总参数量: {total_params}")
print(f"以k为单位的参数量: {params_in_k:.2f}k")
print(f"输出形状: {output_shape}")
# Out:
# 模型总参数量: 1051
# 以k为单位的参数量: 1.05k
# 输出形状: torch.Size([1, 3])
